# %%
# Importing Packages

import numpy as np
import matplotlib.pyplot as plt
import time

from typing import Optional, Union

import jax
import jax.numpy as jnp
from jax.scipy.special import erf
from jax import jit, vmap, block_until_ready, config

from rl_algos.ppo_clipped_normal import PPO_make_train as PPO_Clipped_make_train

# %%
# Seeding everything

seed = 30

rng = jax.random.PRNGKey(seed)
rng, _rng = jax.random.split(rng)

# %%
# Defining Sherbrooke Params and RL Params

tau_0 = 0.783
kappa = 14.31
chi = 0.31 * 2. * jnp.pi
kerr = 0.00
n0 = 53.8
res_amp_scaling = 1/0.348
actual_max_photons = n0 * (1. - 2. * jnp.cos(0.5 * chi * tau_0) * jnp.exp(-0.5 * kappa * tau_0) + jnp.exp(-0.5 * kappa * tau_0))
print(f"Rough Max Photons: {n0}")
print(f"Actual Max Photons: {actual_max_photons}")
nR = 0.01
snr_scale_factor = 1.1
gamma_I = 1/362.9
photon_gamma = 1/4000
init_fid = 1.

time_coeff = 10.0
snr_coeff = 20.0
smoothness_coeff = 10.0
smoothness_baseline_scale = 1.0
apply_smoothing = True
use_processed_action = True
bandwidth = 50.0
freq_relative_cutoff = 0.1
bandwidth_coeff = 0.0
apply_bandwidth_constraint = False
num_t1 = 9.0
photon_weight = 12.0
shot_noise_std = 0.0
standard_fid = 0.99

env_config = {"kappa": kappa,
    "chi": chi,
    "kerr": kerr,
    "time_coeff": time_coeff,
    "snr_coeff": snr_coeff,
    "smoothness_coeff": smoothness_coeff,
    "smoothness_baseline_scale": smoothness_baseline_scale,
    "apply_smoothing": apply_smoothing,
    "use_processed_action": use_processed_action,
    "bandwidth": bandwidth,
    "freq_relative_cutoff": freq_relative_cutoff,
    "bandwidth_coeff": bandwidth_coeff,
    "apply_bandwidth_constraint": apply_bandwidth_constraint,
    "n0": n0,
    "tau_0": tau_0,
    "res_amp_scaling": res_amp_scaling,
    "nR": nR,
    "snr_scale_factor": snr_scale_factor,
    "gamma_I": gamma_I,
    "photon_gamma": photon_gamma,
    "num_t1": num_t1,
    "init_fid": init_fid,
    "photon_weight": photon_weight,
    "standard_fid": standard_fid,
    "shot_noise_std": shot_noise_std,
}

num_envs = 256
num_updates = 4000
config = {
    "LR": 3e-4,
    "NUM_ENVS": num_envs,
    "NUM_STEPS": 1,
    "NUM_UPDATES": num_updates,
    "UPDATE_EPOCHS": 4,
    "NUM_MINIBATCHES": int(num_envs / 64),
    "CLIP_EPS": 0.2,
    "VALUE_CLIP_EPS": 0.2,
    "ENT_COEF": 0.0,
    "VF_COEF": 0.5,
    "MAX_GRAD_NORM": 0.5,
    "ACTIVATION": "relu6",
    "LAYER_SIZE": 128,
    "ENV_NAME": "single_langevin_env",
    "ENV_PARAMS": env_config,
    "ANNEAL_LR": False,
    "DEBUG": True,
    "DEBUG_ACTION": False,
    "PRINT_RATE": 100,
    "ACTION_PRINT_RATE": 100,
}
# Out:
# Rough Max Photons: 53.8
# Actual Max Photons: 53.711451977836106

# %% [markdown]
# ## Varying Kappa

# %%
param_error = 0.05
param_error_array = jnp.array([1 - param_error, 1. ,1. + param_error])
kappas = kappa * param_error_array
chis = chi * param_error_array

single_train_kappa_2 = jit(PPO_Clipped_make_train(config), static_argnums=-1)

print(f"Starting a Run of {num_updates} Updates")
start = time.time()
single_result_k2 = single_train_kappa_2(
    _rng, 
    num_envs)
end = time.time()
print(f"time taken: {end - start}")
# Out:
# Starting a Run of 4000 Updates
# global update: 100
# reward: -31.329
# max pF: 1.516
# max photon: 45.43
# photon time: 0.9986
# smoothness: 0.009866
# bandwidth: 39.988
# global update: 200
# reward: -20.638
# max pF: 1.605
# max photon: 47.571
# photon time: 0.7224
# smoothness: 0.008218999999999999
# bandwidth: 35.381
# global update: 300
# reward: -8.176
# max pF: 1.663
# max photon: 48.111000000000004
# photon time: 0.6929000000000001
# smoothness: 0.006418
# bandwidth: 32.178
# global update: 400
# reward: 0.655
# max pF: 1.713
# max photon: 48.64
# photon time: 0.7634000000000001
# smoothness: 0.005202
# bandwidth: 29.72
# global update: 500
# reward: 8.279
# max pF: 1.7710000000000001
# max photon: 49.967
# photon time: 0.664
# smoothness: 0.004024
# bandwidth: 24.971
# global update: 600
# reward: 14.194
# max pF: 1.829
# max photon: 51.029
# photon time: 0.5807
# smoothness: 0.0035039999999999997
# bandwidth: 22.778000000000002
# global update: 700
# reward: 16.644000000000002
# max pF: 1.821
# max photon: 50.943
# photon time: 0.5468000000000001
# smoothness: 0.003068
# bandwidth: 22.76
# global update: 800
# reward: 19.415
# max pF: 1.848
# max photon: 50.965
# photon time: 0.5850000000000001
# smoothness: 0.00281
# bandwidth: 21.479
# global update: 900
# reward: 21.505
# max pF: 1.865
# max photon: 51.239000000000004
# photon time: 0.6179
# smoothness: 0.002523
# bandwidth: 19.581
# global update: 1000
# reward: 22.91
# max pF: 1.877
# max photon: 51.187
# photon time: 0.6067
# smoothness: 0.002384
# bandwidth: 19.36
# global update: 1100
# reward: 23.925
# max pF: 1.889
# max photon: 50.761
# photon time: 0.5973
# smoothness: 0.0022849999999999997
# bandwidth: 18.725
# global update: 1200
# reward: 25.072
# max pF: 1.8860000000000001
# max photon: 51.466
# photon time: 0.6044
# smoothness: 0.002195
# bandwidth: 18.811
# global update: 1300
# reward: 26.256
# max pF: 1.905
# max photon: 51.474000000000004
# photon time: 0.6111
# smoothness: 0.002142
# bandwidth: 20.0
# global update: 1400
# reward: 26.484
# max pF: 1.9040000000000001
# max photon: 51.69
# photon time: 0.6362
# smoothness: 0.002098
# bandwidth: 20.222
# global update: 1500
# reward: 27.057000000000002
# max pF: 1.905
# max photon: 51.792
# photon time: 0.5443
# smoothness: 0.002088
# bandwidth: 19.785
# global update: 1600
# reward: 27.638
# max pF: 1.921
# max photon: 52.064
# photon time: 0.5664
# smoothness: 0.0020659999999999997
# bandwidth: 20.752
# global update: 1700
# reward: 27.918
# max pF: 1.934
# max photon: 52.427
# photon time: 0.6127
# smoothness: 0.002015
# bandwidth: 20.117
# global update: 1800
# reward: 28.112000000000002
# max pF: 1.925
# max photon: 51.59
# photon time: 0.5683
# smoothness: 0.002041
# bandwidth: 18.306
# global update: 1900
# reward: 27.886
# max pF: 1.935
# max photon: 52.425000000000004
# photon time: 0.6295000000000001
# smoothness: 0.002009
# bandwidth: 18.725
# global update: 2000
# reward: 28.6
# max pF: 1.926
# max photon: 51.607
# photon time: 0.5612
# smoothness: 0.002111
# bandwidth: 20.277
# global update: 2100
# reward: 28.747
# max pF: 1.946
# max photon: 52.509
# photon time: 0.6248
# smoothness: 0.002079
# bandwidth: 19.138
# global update: 2200
# reward: 29.261
# max pF: 1.926
# max photon: 51.824
# photon time: 0.5939
# smoothness: 0.002026
# bandwidth: 21.183
# global update: 2300
# reward: 30.048000000000002
# max pF: 1.948
# max photon: 52.108000000000004
# photon time: 0.5596
# smoothness: 0.002054
# bandwidth: 20.45
# global update: 2400
# reward: 29.674
# max pF: 1.934
# max photon: 51.586
# photon time: 0.5979
# smoothness: 0.002007
# bandwidth: 20.819
# global update: 2500
# reward: 30.336000000000002
# max pF: 1.951
# max photon: 52.267
# photon time: 0.5464
# smoothness: 0.001987
# bandwidth: 20.727
# global update: 2600
# reward: 30.13
# max pF: 1.955
# max photon: 52.458
# photon time: 0.6146
# smoothness: 0.002046
# bandwidth: 21.09
# global update: 2700
# reward: 30.837
# max pF: 1.963
# max photon: 52.415
# photon time: 0.5696
# smoothness: 0.002071
# bandwidth: 22.267
# global update: 2800
# reward: 30.781000000000002
# max pF: 1.954
# max photon: 52.029
# photon time: 0.5456
# smoothness: 0.0020629999999999997
# bandwidth: 23.16
# global update: 2900
# reward: 31.18
# max pF: 1.966
# max photon: 52.603
# photon time: 0.5168
# smoothness: 0.002033
# bandwidth: 21.996000000000002
# global update: 3000
# reward: 31.307000000000002
# max pF: 1.96
# max photon: 52.375
# photon time: 0.5406000000000001
# smoothness: 0.002064
# bandwidth: 20.665
# global update: 3100
# reward: 31.351
# max pF: 1.96
# max photon: 52.013
# photon time: 0.5382
# smoothness: 0.001969
# bandwidth: 21.688
# global update: 3200
# reward: 31.470000000000002
# max pF: 1.965
# max photon: 52.03
# photon time: 0.5538000000000001
# smoothness: 0.002082
# bandwidth: 22.088
# global update: 3300
# reward: 31.354
# max pF: 1.97
# max photon: 52.696
# photon time: 0.5763
# smoothness: 0.00213
# bandwidth: 21.374
# global update: 3400
# reward: 32.055
# max pF: 1.966
# max photon: 52.421
# photon time: 0.542
# smoothness: 0.0020169999999999997
# bandwidth: 20.142
# global update: 3500
# reward: 32.234
# max pF: 1.98
# max photon: 52.615
# photon time: 0.5363
# smoothness: 0.002033
# bandwidth: 19.372
# global update: 3600
# reward: 32.156
# max pF: 1.959
# max photon: 51.632
# photon time: 0.5345
# smoothness: 0.0019329999999999998
# bandwidth: 19.914
# global update: 3700
# reward: 32.617
# max pF: 1.972
# max photon: 52.443
# photon time: 0.537
# smoothness: 0.002028
# bandwidth: 16.68
# global update: 3800
# reward: 32.876
# max pF: 1.98
# max photon: 52.702
# photon time: 0.5268
# smoothness: 0.002079
# bandwidth: 18.657
# global update: 3900
# reward: 32.2
# max pF: 1.974
# max photon: 52.448
# photon time: 0.5975
# smoothness: 0.002108
# bandwidth: 23.203
# global update: 4000
# reward: 32.919000000000004
# max pF: 1.986
# max photon: 53.058
# photon time: 0.5193
# smoothness: 0.002133
# bandwidth: 21.177
# time taken: 486.5682330131531

# %%
import copy

config_2 = copy.deepcopy(config)
config_2["ENV_PARAMS"]["kappa"] = kappas[0]

config_2

# %%
single_train_kappa_1 = jit(PPO_Clipped_make_train(config_2), static_argnums=-1)

print(f"Starting a Run of {num_updates} Updates")
start = time.time()
single_result_k1 = single_train_kappa_1(
    _rng, 
    num_envs)
end = time.time()
print(f"time taken: {end - start}")

# %%
config_3 = copy.deepcopy(config)
config_3["ENV_PARAMS"]["kappa"] = kappas[2]
config_3["ENV_PARAMS"]["num_t1"] = 7.0

config_3

# %%
single_train_kappa_3 = jit(PPO_Clipped_make_train(config_3), static_argnums=-1)

print(f"Starting a Run of {num_updates} Updates")
start = time.time()
single_result_k3 = single_train_kappa_3(
    _rng, 
    num_envs)
end = time.time()
print(f"time taken: {end - start}")

# %%
metric_k1 = single_result_k1["metrics"]
metric_k2 = single_result_k2["metrics"]
metric_k3 = single_result_k3["metrics"]

actions_k1 = metric_k1["action"]
actions_k2 = metric_k2["action"]
actions_k3 = metric_k3["action"]

photon_times_k1 = metric_k1["photon time"][-1, 0]
photon_times_k2 = metric_k2["photon time"][-1, 0]
photon_times_k3 = metric_k3["photon time"][-1, 0]

# %%
from utils import photon_env_dicts

env = photon_env_dicts()[config["ENV_NAME"]](**env_config)

# %%
raw_final_action_k1 = actions_k1[-1, 0]
raw_final_action_k2 = actions_k2[-1, 0]
raw_final_action_k3 = actions_k3[-1, 0]

ts_mod = env.ts_action / param_error_array[2] / (config["ENV_PARAMS"]["num_t1"]) * config_3["ENV_PARAMS"]["num_t1"]

raw_smooth_action_k1 = env.prepare_action(raw_final_action_k1) * jnp.heaviside(photon_times_k1 - env.ts_action / param_error_array[0], 0.)
raw_smooth_action_k2 = env.prepare_action(raw_final_action_k2) * jnp.heaviside(photon_times_k2 - env.ts_action / param_error_array[0], 0.)
raw_smooth_action_k3 = env.prepare_action(raw_final_action_k3) * jnp.heaviside(photon_times_k3 - ts_mod, 0.)

# %%
# Comparing Kappa Waveforms

# Divide Time by Error Percentage because it corresponds to change in timescale
# Amplitude can be left as it is because we would deal with normalized waveforms
# So absolute values aren't relevant, only the waveform shapes

plt.plot(env.ts_action / param_error_array[0], -raw_smooth_action_k1, label='Low Kappa')
plt.plot(env.ts_action / param_error_array[1], -raw_smooth_action_k2, label='Normal Kappa')
plt.plot(ts_mod, -raw_smooth_action_k3, label='High Kappa')
plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Amplitude (A.U.)')
plt.show()

# %% [markdown]
# ## Chi Variance

# %%
config_4 = copy.deepcopy(config)
config_4["ENV_PARAMS"]["chi"] = chis[0]

config_4

# %%
single_train_chi_1 = jit(PPO_Clipped_make_train(config_4), static_argnums=-1)

print(f"Starting a Run of {num_updates} Updates")
start = time.time()
single_result_c1 = single_train_chi_1(
    _rng, 
    num_envs)
end = time.time()
print(f"time taken: {end - start}")

# %%
config_5 = copy.deepcopy(config)
config_5["ENV_PARAMS"]["chi"] = chis[1]

config_5

# %%
single_train_chi_2 = jit(PPO_Clipped_make_train(config_5), static_argnums=-1)

print(f"Starting a Run of {num_updates} Updates")
start = time.time()
single_result_c2 = single_train_chi_2(
    _rng, 
    num_envs)
end = time.time()
print(f"time taken: {end - start}")

# %%
config_6 = copy.deepcopy(config)
config_6["ENV_PARAMS"]["chi"] = chis[2]

config_6

# %%
single_train_chi_3 = jit(PPO_Clipped_make_train(config_6), static_argnums=-1)

print(f"Starting a Run of {num_updates} Updates")
start = time.time()
single_result_c3 = single_train_chi_3(
    _rng, 
    num_envs)
end = time.time()
print(f"time taken: {end - start}")

# %%
metric_c1 = single_result_c1["metrics"]
metric_c2 = single_result_c2["metrics"]
metric_c3 = single_result_c3["metrics"]

actions_c1 = metric_c1["action"]
actions_c2 = metric_c2["action"]
actions_c3 = metric_c3["action"]

# %%
raw_final_action_c1 = actions_c1[-1, 0]
raw_final_action_c2 = actions_c2[-1, 0]
raw_final_action_c3 = actions_c3[-1, 0]

raw_smooth_action_c1 = env.prepare_action(raw_final_action_c1)
raw_smooth_action_c2 = env.prepare_action(raw_final_action_c2)
raw_smooth_action_c3 = env.prepare_action(raw_final_action_c3)

# %%
# Comparing Chi Waveforms

plt.plot(env.ts_action, raw_smooth_action_c1, label='Low Chi')
plt.plot(env.ts_action, raw_smooth_action_c2, label='Normal Chi')
plt.plot(env.ts_action, raw_smooth_action_c3, label='High Chi')
plt.legend()
plt.xlabel('Time (us)')
plt.ylabel('Amplitude (A.U.)')
plt.show()
